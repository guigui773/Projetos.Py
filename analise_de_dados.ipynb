# %%
import json
import matplotlib.pyplot as plt

dados_json = '''
{
  "dados": [
    {
      "ano": 2019,
      "regiao": "Norte",
      "rendimento_medio": 1000,
      "taxa_desemprego": 10
    },
    {
      "ano": 2019,
      "regiao": "Nordeste",
      "rendimento_medio": 1100,
      "taxa_desemprego": 9
    },
    {
      "ano": 2019,
      "regiao": "Sudeste",
      "rendimento_medio": 1200,
      "taxa_desemprego": 8
    },
    {
      "ano": 2019,
      "regiao": "Sul",
      "rendimento_medio": 1300,
      "taxa_desemprego": 7
    },
    {
      "ano": 2020,
      "regiao": "Norte",
      "rendimento_medio": 1050,
      "taxa_desemprego": 11
    },
    {
      "ano": 2020,
      "regiao": "Nordeste",
      "rendimento_medio": 1120,
      "taxa_desemprego": 10
    },
    {
      "ano": 2020,
      "regiao": "Sudeste",
      "rendimento_medio": 1250,
      "taxa_desemprego": 9
    },
    {
      "ano": 2020,
      "regiao": "Sul",
      "rendimento_medio": 1350,
      "taxa_desemprego": 8
    },
    {
      "ano": 2021,
      "regiao": "Norte",
      "rendimento_medio": 1100,
      "taxa_desemprego": 9.5
    },
    {
      "ano": 2021,
      "regiao": "Nordeste",
      "rendimento_medio": 1150,
      "taxa_desemprego": 9.2
    },
    {
      "ano": 2021,
      "regiao": "Sudeste",
      "rendimento_medio": 1270,
      "taxa_desemprego": 8.7
    },
    {
      "ano": 2021,
      "regiao": "Sul",
      "rendimento_medio": 1375,
      "taxa_desemprego": 8.3
    },
    {
      "ano": 2022,
      "regiao": "Norte",
      "rendimento_medio": 1125,
      "taxa_desemprego": 9.2
    },
    {
      "ano": 2022,
      "regiao": "Nordeste",
      "rendimento_medio": 1180,
      "taxa_desemprego": 9
    },
    {
      "ano": 2022,
      "regiao": "Sudeste",
      "rendimento_medio": 1305,
      "taxa_desemprego": 8.5
    },
    {
      "ano": 2022,
      "regiao": "Sul",
      "rendimento_medio": 1400,
      "taxa_desemprego": 8.1
    }
  ]
}
'''

dados = json.loads(dados_json)

regioes = set(dado["regiao"] for dado in dados["dados"])

plt.figure(figsize=(12, 8))

for regiao in regioes:
    dados_regiao = [dado for dado in dados["dados"] if dado["regiao"] == regiao]
    anos = [dado["ano"] for dado in dados_regiao]
    rendimentos = [dado["rendimento_medio"] for dado in dados_regiao]
    taxas_desemprego = [dado["taxa_desemprego"] for dado in dados_regiao]

    plt.scatter(rendimentos, taxas_desemprego, label=f'{regiao}', s=100)


plt.xlabel('Rendimento Médio')
plt.ylabel('Taxa de Desemprego')
plt.title('Rendimento Médio vs. Taxa de Desemprego por Região (2019-2022)')
plt.grid(True)
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

dados = [
  {
    "empresa": "Intel",
    "investimento_pd": 10000000000,
    "lucro_anual": 5000000000
  },
  {
    "empresa": "Microsoft",
    "investimento_pd": 8000000000,
    "lucro_anual": 4000000000
  },
  {
    "empresa": "Apple",
    "investimento_pd": 7000000000,
    "lucro_anual": 3500000000
  },
  {
    "empresa": "Amazon",
    "investimento_pd": 6000000000,
    "lucro_anual": 3000000000
  },
  {
    "empresa": "Alphabet",
    "investimento_pd": 5000000000,
    "lucro_anual": 2500000000
  },
  {
    "empresa": "Samsung",
    "investimento_pd": 4000000000,
    "lucro_anual": 2000000000
  },
  {
    "empresa": "Huawei",
    "investimento_pd": 3000000000,
    "lucro_anual": 1500000000
  },
  {
    "empresa": "Sony",
    "investimento_pd": 2000000000,
    "lucro_anual": 1000000000
  },
  {
    "empresa": "Toyota",
    "investimento_pd": 1000000000,
    "lucro_anual": 500000000
  }
]

investimento_pd = [dado["investimento_pd"] for dado in dados]
lucro_anual = [dado["lucro_anual"] for dado in dados]
nomes = [dado["empresa"] for dado in dados]

plt.scatter(investimento_pd, lucro_anual, label=nomes)

plt.xlabel("Investimento em P&D (R$)")
plt.ylabel("Lucro anual (R$)")
plt.title('Investimento em P&D vs Lucro anual')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

dados = [
  {
    "cidade": "São Paulo",
    "qualidade_ar": 51,
    "taxa_diagnostico_asma": 10
  },
  {
    "cidade": "Rio de Janeiro",
    "qualidade_ar": 52,
    "taxa_diagnostico_asma": 11
  },
  {
    "cidade": "Belo Horizonte",
    "qualidade_ar": 53,
    "taxa_diagnostico_asma": 12
  },
  {
    "cidade": "Brasília",
    "qualidade_ar": 54,
    "taxa_diagnostico_asma": 13
  },
  {
    "cidade": "Curitiba",
    "qualidade_ar": 55,
    "taxa_diagnostico_asma": 14
  },
  {
    "cidade": "Porto Alegre",
    "qualidade_ar": 56,
    "taxa_diagnostico_asma": 15
  },
  {
    "cidade": "Salvador",
    "qualidade_ar": 57,
    "taxa_diagnostico_asma": 16
  },
  {
    "cidade": "Recife",
    "qualidade_ar": 58,
    "taxa_diagnostico_asma": 17
  },
  {
    "cidade": "Fortaleza",
    "qualidade_ar": 59,
    "taxa_diagnostico_asma": 18
  },
  {
    "cidade": "Manaus",
    "qualidade_ar": 60,
    "taxa_diagnostico_asma": 19
  },
  {
    "cidade": "Belém",
    "qualidade_ar": 61,
    "taxa_diagnostico_asma": 20
  }
]

qualidade_ar = [dado["qualidade_ar"] for dado in dados]
taxa_diagnostico_asma = [dado["taxa_diagnostico_asma"] for dado in dados]
nomes = [dado["cidade"] for dado in dados]

plt.scatter(qualidade_ar, taxa_diagnostico_asma)

plt.xlabel("Qualidade do ar (IQA)")
plt.ylabel("Taxa de diagnóstico de asma")
plt.title('Qualidade do ar vs Taxa de diagnostico de asma')
plt.grid(True)

for i, cidade in enumerate(nomes):
  plt.annotate(cidade, (qualidade_ar[i], taxa_diagnostico_asma[i]))

plt.show()

# %%
import matplotlib.pyplot as plt

dados = [
  {
    "pais": "Finlândia",
    "indice_felicidade": 7.822,
    "gastos_saude_per_capita": 5.101
  },
  {
    "pais": "Dinamarca",
    "indice_felicidade": 7.627,
    "gastos_saude_per_capita": 5.698
  },
  {
    "pais": "Islândia",
    "indice_felicidade": 7.554,
    "gastos_saude_per_capita": 6.038
  },
  {
    "pais": "Noruega",
    "indice_felicidade": 7.494,
    "gastos_saude_per_capita": 5.677
  },
  {
    "pais": "Suíça",
    "indice_felicidade": 7.462,
    "gastos_saude_per_capita": 5.998
  },
  {
    "pais": "Países Baixos",
    "indice_felicidade": 7.444,
    "gastos_saude_per_capita": 5.262
  },
  {
    "pais": "Austrália",
    "indice_felicidade": 7.363,
    "gastos_saude_per_capita": 5.876
  },
  {
    "pais": "Nova Zelândia",
    "indice_felicidade": 7.325,
    "gastos_saude_per_capita": 5.677
  },
  {
    "pais": "Canadá",
    "indice_felicidade": 7.265,
    "gastos_saude_per_capita": 5.162
  },
  {
    "pais": "Irlanda",
    "indice_felicidade": 7.256,
    "gastos_saude_per_capita": 5.024
  },
  {
    "pais": "Luxemburgo",
    "indice_felicidade": 7.245,
    "gastos_saude_per_capita": 6.224
  },
  {
    "pais": "Áustria",
    "indice_felicidade": 7.190,
    "gastos_saude_per_capita": 5.498
  },
  {
    "pais": "Suécia",
    "indice_felicidade": 7.183,
    "gastos_saude_per_capita": 5.677
  },
  {
    "pais": "França",
    "indice_felicidade": 7.146,
    "gastos_saude_per_capita": 5.162
  }
]

indice_felicidade = [dado["indice_felicidade"] for dado in dados]
gastos_saude_per_capita = [dado["gastos_saude_per_capita"] for dado in dados]
nomes = [dado["pais"] for dado in dados]

plt.scatter(indice_felicidade, gastos_saude_per_capita)

for i, nome in enumerate(nomes):
  plt.annotate(nome, (indice_felicidade[i], gastos_saude_per_capita[i]))

plt.title("Índice de felicidade e gastos em saúde per capita")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Importando os dados
dados = [
  {
    "idade_mae": 25,
    "peso_bebe": 3.500
  },
  {
    "idade_mae": 26,
    "peso_bebe": 3.300
  },
  {
    "idade_mae": 27,
    "peso_bebe": 3.200
  },
  {
    "idade_mae": 28,
    "peso_bebe": 3.100
  },
  {
    "idade_mae": 29,
    "peso_bebe": 3.000
  },
  {
    "idade_mae": 30,
    "peso_bebe": 2.900
  },
  {
    "idade_mae": 31,
    "peso_bebe": 2.800
  },
  {
    "idade_mae": 32,
    "peso_bebe": 2.700
  },
  {
    "idade_mae": 33,
    "peso_bebe": 2.600
  },
  {
    "idade_mae": 34,
    "peso_bebe": 2.500
  },
  {
    "idade_mae": 35,
    "peso_bebe": 2.400
  },
  {
    "idade_mae": 36,
    "peso_bebe": 2.300
  },
  {
    "idade_mae": 37,
    "peso_bebe": 2.200
  },
  {
    "idade_mae": 38,
    "peso_bebe": 2.100
  },
  {
    "idade_mae": 39,
    "peso_bebe": 2.000
  },
  {
    "idade_mae": 40,
    "peso_bebe": 1.900
  }
]

idade_mae = [dado["idade_mae"] for dado in dados]
peso_bebe = [dado["peso_bebe"] for dado in dados]

plt.scatter(idade_mae, peso_bebe)

plt.title("Idade da mãe vs. peso do bebê")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Importando os dados
dados = [
  {
    "pais": "Brasil",
    "consumo_calorias": 2.800,
    "expectativa_de_vida": 73,
  },
  {
    "pais": "Estados Unidos",
    "consumo_calorias": 3.500,
    "expectativa_de_vida": 78,
  },
  {
    "pais": "Japão",
    "consumo_calorias": 2.500,
    "expectativa_de_vida": 83,
  },
  {
    "pais": "China",
    "consumo_calorias": 2.200,
    "expectativa_de_vida": 76,
  },
  {
    "pais": "Índia",
    "consumo_calorias": 2.100,
    "expectativa_de_vida": 70,
  },
  {
    "pais": "África do Sul",
    "consumo_calorias": 2.700,
    "expectativa_de_vida": 64,
  },
  {
    "pais": "Alemanha",
    "consumo_calorias": 3.000,
    "expectativa_de_vida": 82,
  },
  {
    "pais": "França",
    "consumo_calorias": 2.800,
    "expectativa_de_vida": 82,
  },
  {
    "pais": "Itália",
    "consumo_calorias": 2.900,
    "expectativa_de_vida": 83,
  },
]

consumo_calorias = [dado["consumo_calorias"] for dado in dados]
expectativa_de_vida = [dado["expectativa_de_vida"] for dado in dados]
nomes = [dado["pais"] for dado in dados]

plt.scatter(consumo_calorias, expectativa_de_vida)

plt.title("Consumo de calorias vs. expectativa de vida")
plt.grid(True)

for i, nome in enumerate(nomes):
  plt.annotate(nome, (consumo_calorias[i], expectativa_de_vida[i]))

plt.show()

# %%
import matplotlib.pyplot as plt
import json


data = [
    {
      "distancia_do_centro": 0,
      "preco_medio": 10.000,
      "quantidade_imoveis": 100
    },
    {
      "distancia_do_centro": 1,
      "preco_medio": 9.000,
      "quantidade_imoveis": 90
    },
    {
      "distancia_do_centro": 2,
      "preco_medio": 8.000,
      "quantidade_imoveis": 80
    },
    {
      "distancia_do_centro": 50,
      "preco_medio": 3.000,
      "quantidade_imoveis": 30
    },
    {
      "distancia_do_centro": 100,
      "preco_medio": 1.000,
      "quantidade_imoveis": 10
    }
  ]


plt.scatter([x["distancia_do_centro"] for x in data], [x["preco_medio"] for x in data])

plt.xlabel("Distância do centro (km)")
plt.ylabel("Preço do M² (R$)")
plt.title("Valor do M² vs distancia do centro")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [
    {
      "taxa_criminalidade": 10,
      "gastos_educacao": 10
    },
    {
      "taxa_criminalidade": 20,
      "gastos_educacao": 20
    },
    {
      "taxa_criminalidade": 30,
      "gastos_educacao": 30
    },
    {
      "taxa_criminalidade": 40,
      "gastos_educacao": 40
    },
    {
      "taxa_criminalidade": 50,
      "gastos_educacao": 50
    }
  ]


plt.scatter([x["taxa_criminalidade"] for x in data], [x["gastos_educacao"] for x in data])

plt.title("Taxa de criminalidade vs. gastos em educação")
plt.xlabel("Taxa de criminalidade")
plt.ylabel("Gastos em educação")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import json

x = [40, 45, 35, 50, 42, 38, 47, 44, 39]
y = [7, 8, 6, 9, 7.5, 5, 8.5, 7.2, 6.5]


data = [

    {
      "h_trab": 40,
      "idc_sas": 7,
    },
     {
      "h_trab": 45,
      "idc_sas": 8,
    },
     {
      "h_trab": 35,
      "idc_sas": 9,
    },
     {
      "h_trab": 50,
      "idc_sas": 7.5,
    },
    {
      "h_trab": 42,
      "idc_sas": 5,
    },
    {
      "h_trab": 38,
      "idc_sas": 8.5,
    },
    {
      "h_trab": 47,
      "idc_sas": 7.2,
    },
    {
      "h_trab": 39,
      "idc_sas": 6.5,
    },
      ]

plt.scatter([x["h_trab"] for x in data], [x["idc_sas"] for x in data])
plt.xlabel("Horário de Trabalho (horas/semana)")
plt.ylabel("Satisfação no Trabalho (escala de 0 a 10)")
plt.title("Quantidade de horas trabalhadas VS. Indice de satisfação")
plt.grid(True)
plt.show()

# %%
import json
import matplotlib.pyplot as plt


dados = [
  {
    "pais": "Alemanha",
    "idh": 0.952,
    "consumo_energia_per_capita": 6.35
  },
  {
    "pais": "Austrália",
    "idh": 0.944,
    "consumo_energia_per_capita": 7.47
  },
  {
    "pais": "Áustria",
    "idh": 0.943,
    "consumo_energia_per_capita": 5.97
  },
  {
    "pais": "Brasil",
    "idh": 0.942,
    "consumo_energia_per_capita": 7.35
  },
]

plt.scatter([x ["idh"]for x in dados] , [x ["consumo_energia_per_capita"] for x in dados])
plt.xlabel("IDH")
plt.ylabel("Consumo de energia per capita")
plt.title("Desenvolvimento Humano vs Consumo de Energia Per Capita")
plt.grid(True)

plt.show()

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>O que é o Colab?</h2>
# </div>
#
# O Colab, ou "Colaboratory", permite escrever e executar Python no navegador e conta com o seguinte:
# - Nenhuma configuração necessária
# - Acesso a GPUs sem custo financeiro
# - Compartilhamento fácil
#
# Você pode ser um <strong>estudante</strong>, um <strong>cientista de dados</strong> ou um <strong>pesquisador de IA</strong>, o Colab pode facilitar seu trabalho. Assista ao vídeo <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introdução ao Colab</a> para saber mais ou simplesmente comece a usá-lo abaixo!
